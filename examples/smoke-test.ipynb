# %% [markdown]
# # Notebook Bridge Smoke Test
#
# This notebook is a small manual test fixture for the VS Code bridge.

# %%
name = "notebook-bridge"
print(f"hello from {name}")

# %%
items = [1, 2, 3]
total = sum(items)

for item in items:
    print(item)

print("total:", total)
